# %% [markdown]
# <a href="https://colab.research.google.com/github/HuyNguyen271/Bai_tap_tuan_01/blob/main/50_startups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = '/content/sample_data/50_Startups.csv'

data = pd.read_csv(url)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# am la ti le nghich
#duong la ti le thuan
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='red')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = '/content/sample_data/50_Startups.csv'

data = pd.read_csv(url)



model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['R&D Spend']),y=data['Profit'])

print('Gia tri Intercept bac 1 la: ',model.intercept_)
print('Gia tri Coeffient bac 1 la: ',model.coef_)
print('Gia tri Score bac 1 la: ',model.score(pd.DataFrame(data['R&D Spend']),data['Profit']))

data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='red')
model.score(pd.DataFrame(data['R&D Spend']),data['Profit'])

y_pred = model.predict(pd.DataFrame(data['R&D Spend']))
plt.plot(data['R&D Spend'],y_pred,color='blue')
# Out:
# Gia tri Intercept bac 1 la:  49032.89914125215
# Gia tri Coeffient bac 1 la:  [0.85429137]
# Gia tri Score bac 1 la:  0.9465353160804393
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = '/content/sample_data/50_Startups.csv'
data = pd.read_csv(url)



model = linear_model.LinearRegression()


X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T,y=data['Profit'])

print('Gia tri Intercept bac 2 la: ',model.intercept_)
print('Gia tri Coeffient bac 2 la: ',model.coef_)
print('Gia tri Score bac 2 la: ',model.score(X,data['Profit']))

range = np.arange(0,150000,0.1)

X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(pd.DataFrame([range,range**2]).T)

data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='green',xlim=(-5000,160000))
plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept bac 2 la:  48128.14916956878
# Gia tri Coeffient bac 2 la:  [ 8.90147291e-01 -2.31821806e-07]
# Gia tri Score bac 2 la:  0.946703652909133
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = '/content/sample_data/50_Startups.csv'
data = pd.read_csv(url)


model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T,y=data['Profit'])

print('Gia tri Intercept bac 3 la:',model.intercept_)
print('Gia tri Coeffient bac 3 la:',model.coef_)
print('Gia tri Score bac 3 la: ',model.score(X,data['Profit']))

range = np.arange(0,150000,0.1)

X_range = pd.DataFrame([range,range**2,range,range**3]).T
y_pred = model.predict(pd.DataFrame([range,range**2,range**3]).T)

data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='green',xlim=(-5000,160000))

plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept bac 3 la: 43108.76756818297
# Gia tri Coeffient bac 3 la: [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Gia tri Score bac 3 la:  0.9540709421464032
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = '/content/sample_data/50_Startups.csv'
data = pd.read_csv(url)


model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5]).T
model.fit(X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5]).T,y=data['Profit'])

print('Gia tri Intercept bac 5 la: ',model.intercept_)
print('Gia tri Coeffient bac 5 la: ',model.coef_)
print('Gia tri Score bac 5 la:  ',model.score(X,data['Profit']))

range = np.arange(0,150000,0.1)

X_range = pd.DataFrame([range,range**2,range,range**3,range**4,range**5]).T
y_pred = model.predict(pd.DataFrame([range,range**2,range**3,range**4,range**5]).T)

data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='green',xlim=(-5000,160000))
plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept bac 5 la:  62755.68248568247
# Gia tri Coeffient bac 5 la:  [ 1.32995066e-19  1.41519102e-14  3.43374411e-10 -3.89058927e-15
#   1.21062645e-20]
# Gia tri Score bac 5 la:   0.9088995842501878
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = '/content/sample_data/50_Startups.csv'
data = pd.read_csv(url)


model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5,data['R&D Spend']**6
                  ,data['R&D Spend']**7,data['R&D Spend']**8]).T
model.fit(X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5,
                          data['R&D Spend']**6,data['R&D Spend']**7,data['R&D Spend']**8]).T,y=data['Profit'])

print('Gia tri Intercept bac 8 la: ',model.intercept_)
print('Gia tri Coeffient bac 8 la: ',model.coef_)
print('Gia tri Score bac 8 la:  ',model.score(X,data['Profit']))

range = np.arange(0,150000,0.1)

X_range = pd.DataFrame([range,range**2,range,range**3,range**4,range**5,range**6,range**7,range**8]).T
y_pred = model.predict(pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8]).T)

data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='green',xlim=(-5000,160000))
plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept bac 8 la:  80864.56840794317
# Gia tri Coeffient bac 8 la:  [ 1.43616056e-49 -2.59683983e-29 -1.39012193e-35  1.11485032e-34
#   7.43922541e-30  3.33945123e-25 -4.09627579e-30  1.27850329e-35]
# Gia tri Score bac 8 la:   0.7875062179748802
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = '/content/sample_data/50_Startups.csv'
data = pd.read_csv(url)


model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5,data['R&D Spend']**6,data['R&D Spend']**7,data['R&D Spend']**8,data['R&D Spend']**9,data['R&D Spend']**10]).T
model.fit(X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5,data['R&D Spend']**6,data['R&D Spend']**7,data['R&D Spend']**8,data['R&D Spend']**9,data['R&D Spend']**10]).T,y=data['Profit'])

print('Gia tri Intercept bac 10 la: ',model.intercept_)
print('Gia tri Coeffient bac 10 la: ',model.coef_)
print('Gia tri Score bac 10 la:  ',model.score(X,data['Profit']))

range = np.arange(0,150000,0.1)

X_range = pd.DataFrame([range,range**2,range,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T)

data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9),color='green',xlim=(-5000,160000))
plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept bac 10 la:  88222.34536583656
# Gia tri Coeffient bac 10 la:  [ 5.51258424e-70 -2.84081425e-39  1.36361271e-45  3.26751007e-66
#   7.14930577e-50  6.00188335e-45  4.22025487e-40  1.99075980e-35
#  -2.43124781e-40  7.49857982e-46]
# Gia tri Score bac 10 la:   0.7054994430986499
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
